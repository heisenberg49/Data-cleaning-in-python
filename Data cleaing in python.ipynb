# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
df = pd.read_csv('C:/Users/prem/Documents/Temp_data.csv')

# %%
df
# Out:
#    Temprature  Humidity
# 0          36      45.0
# 1          25       NaN
# 2         NaN      26.0
# 3          32      21.0
# 4          25      32.0
# 5          21       NaN
# 6         N/a      12.0
# 7           8       NaN
# 8          36      35.0
# 9         NaN      32.0
# 10         29       NaN
# 11         na      12.0
# 12         10      24.0

# %%
df.isnull().sum()
# Out:
# Temprature    2
# Humidity      4
# dtype: int64

# %% [markdown]
# # detecting Na na and N/a Values

# %% [markdown]
# Pandas is not recognising N/a or na as null values

# %%
missing_values = ["na","N/a"]
df = pd.read_csv('C:/Users/prem/Documents/Temp_data.csv', na_values = missing_values)

# %%
df.isnull().sum()
# Out:
# Temprature    4
# Humidity      4
# dtype: int64

# %% [markdown]
# now we got 4 null values in temprature column instead of 2

# %% [markdown]
# # visualizing null values with seaborn

# %%
sns.heatmap(df.isnull(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # removing na values

# %%
df
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0       NaN
# 2          NaN      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0       NaN
# 6          NaN      12.0
# 7          8.0       NaN
# 8         36.0      35.0
# 9          NaN      32.0
# 10        29.0       NaN
# 11         NaN      12.0
# 12        10.0      24.0

# %%
df.dropna()
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 3         32.0      21.0
# 4         25.0      32.0
# 8         36.0      35.0
# 12        10.0      24.0

# %% [markdown]
# all na values are being removed

# %% [markdown]
# # Replacing na with some values

# %%
df.fillna(0)
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0       0.0
# 2          0.0      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0       0.0
# 6          0.0      12.0
# 7          8.0       0.0
# 8         36.0      35.0
# 9          0.0      32.0
# 10        29.0       0.0
# 11         0.0      12.0
# 12        10.0      24.0

# %% [markdown]
# 0 replaced all the na values

# %%
df
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0       NaN
# 2          NaN      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0       NaN
# 6          NaN      12.0
# 7          8.0       NaN
# 8         36.0      35.0
# 9          NaN      32.0
# 10        29.0       NaN
# 11         NaN      12.0
# 12        10.0      24.0

# %% [markdown]
# # forward filling

# %%
df.fillna(method = 'ffill')
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0      45.0
# 2         25.0      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0      32.0
# 6         21.0      12.0
# 7          8.0      12.0
# 8         36.0      35.0
# 9         36.0      32.0
# 10        29.0      32.0
# 11        29.0      12.0
# 12        10.0      24.0

# %% [markdown]
# # backward fill

# %%
df.fillna(method = 'bfill')
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0      26.0
# 2         32.0      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0      12.0
# 6          8.0      12.0
# 7          8.0      35.0
# 8         36.0      35.0
# 9         29.0      32.0
# 10        29.0      12.0
# 11        10.0      12.0
# 12        10.0      24.0

# %%
df
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0       NaN
# 2          NaN      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0       NaN
# 6          NaN      12.0
# 7          8.0       NaN
# 8         36.0      35.0
# 9          NaN      32.0
# 10        29.0       NaN
# 11         NaN      12.0
# 12        10.0      24.0

# %% [markdown]
# # interpolation

# %%
df.interpolate()
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0      35.5
# 2         28.5      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0      22.0
# 6         14.5      12.0
# 7          8.0      23.5
# 8         36.0      35.0
# 9         32.5      32.0
# 10        29.0      22.0
# 11        19.5      12.0
# 12        10.0      24.0

# %% [markdown]
# fill na vlaues = average of below and above value

# %%
df.fillna({
    "Temprature" : 999
})
# Out:
#     Temprature  Humidity
# 0         36.0      45.0
# 1         25.0       NaN
# 2        999.0      26.0
# 3         32.0      21.0
# 4         25.0      32.0
# 5         21.0       NaN
# 6        999.0      12.0
# 7          8.0       NaN
# 8         36.0      35.0
# 9        999.0      32.0
# 10        29.0       NaN
# 11       999.0      12.0
# 12        10.0      24.0

# %% [markdown]
# Substituting na value of Temprature with 999
